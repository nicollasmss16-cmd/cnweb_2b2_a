# %% [markdown]
# <a href="https://colab.research.google.com/github/nicollasmss16-cmd/cnweb_2b2_a/blob/main/aula0323.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def equacao2grau(a, b, c,):
  delta = b**2 - 4*a*c
  if delta < 0:
    return "sem raiz para este número"
  x1 = (-b + math.sprt(delta) / (2*a))
  x2 = (-b + math.sprt(delta) / (2*a))
  return x1, x2

# %%
print(equacao2grau(1, -3, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3419/1216536888.py in <cell line: 0>()
# ----> 1 print(equacao2grau(1, -3, 2))
#
# NameError: name 'equacao2grau' is not defined
